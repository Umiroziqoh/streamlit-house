# %% [markdown]
# # Read Data Set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns  
from sklearn.model_selection import train_test_split  
from sklearn.metrics import r2_score

# %%
dshouse = pd.read_csv('house.csv')

# %%
dshouse
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
dshouse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        1000 non-null   int64
#  1   Num_Bedrooms          1000 non-null   int64
#  2   Num_Bathrooms         1000 non-null   int64
#  3   Year_Built            1000 non-null   int64
#  4   Lot_Size              1000 non-null   float64
#  5   Garage_Size           1000 non-null   int64
#  6   Neighborhood_Quality  1000 non-null   int64
#  7   House_Price           1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %%
independent_column = dshouse.columns[dshouse.columns != 'House_Price']
for column in independent_column :
    plt.figure(figsize=(6, 4))
    sns.regplot(x=dshouse[column],y=dshouse['House_Price'],scatter_kws={'alpha': 0.5},line_kws={"color": "red"})
    plt.xlabel(column)
    plt.ylabel('House_Price')
    plt.title(f'garis regresi {column} vs House Price')
    plt.show()

# %% [markdown]
# # Indemepndet Dependent Variabel

# %%
dshouse = pd.read_csv('house.csv')
x = dshouse.iloc[:, [0, 1, 2, 3, 4, 5, 6]].values
y = dshouse.iloc[:, 7].values

# %%
x
# Out:
# array([[1.36000000e+03, 2.00000000e+00, 1.00000000e+00, ...,
#         5.99636640e-01, 0.00000000e+00, 5.00000000e+00],
#        [4.27200000e+03, 3.00000000e+00, 3.00000000e+00, ...,
#         4.75301385e+00, 1.00000000e+00, 6.00000000e+00],
#        [3.59200000e+03, 1.00000000e+00, 2.00000000e+00, ...,
#         3.63482272e+00, 0.00000000e+00, 9.00000000e+00],
#        ...,
#        [2.60600000e+03, 4.00000000e+00, 2.00000000e+00, ...,
#         4.05506679e+00, 0.00000000e+00, 2.00000000e+00],
#        [4.72300000e+03, 5.00000000e+00, 2.00000000e+00, ...,
#         1.93092148e+00, 0.00000000e+00, 7.00000000e+00],
#        [3.26800000e+03, 4.00000000e+00, 2.00000000e+00, ...,
#         3.10879025e+00, 2.00000000e+00, 2.00000000e+00]])

# %%
y
# Out:
# array([ 262382.85227406,  985260.85449016,  777977.39011858,
#         229698.91866361, 1041740.8589249 ,  879796.98352238,
#         814427.86140899,  703413.11094468,  173875.03721558,
#         504176.50605937,  335332.59275294,  635097.3959198 ,
#         701133.80414712,  440726.28481629,  838719.4305035 ,
#        1019192.6613592 ,  735850.81234216,  234261.64997474,
#         396246.35888875,  672852.051981  ,  586086.56853891,
#         740174.01465508,  370167.09090272,  530824.19677521,
#         227515.30028798,  652166.14236589,  745670.63714772,
#         513161.95119306,  432357.90610274,  434165.89663405,
#         809686.20114353,  883819.09112186,  912468.04790467,
#         281313.06144485,  705923.31489162,  656980.46042822,
#         318266.27713209,  582468.79773652,  541967.63355925,
#         188531.42345711,  565562.75043214,  697574.55566703,
#         666733.47346169,  376388.02162864,  485380.95019563,
# ...

# %% [markdown]
# # Splint Train Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.4,random_state=42)

# %%
x_test
# Out:
# array([[4.01200000e+03, 3.00000000e+00, 1.00000000e+00, ...,
#         2.09809241e+00, 1.00000000e+00, 5.00000000e+00],
#        [2.31000000e+03, 3.00000000e+00, 1.00000000e+00, ...,
#         1.36962237e+00, 1.00000000e+00, 4.00000000e+00],
#        [4.70800000e+03, 1.00000000e+00, 3.00000000e+00, ...,
#         1.79297022e+00, 1.00000000e+00, 8.00000000e+00],
#        ...,
#        [2.31900000e+03, 2.00000000e+00, 2.00000000e+00, ...,
#         8.93968988e-01, 0.00000000e+00, 1.00000000e+00],
#        [2.11900000e+03, 2.00000000e+00, 1.00000000e+00, ...,
#         2.33472097e+00, 0.00000000e+00, 4.00000000e+00],
#        [2.60600000e+03, 4.00000000e+00, 2.00000000e+00, ...,
#         4.05506679e+00, 0.00000000e+00, 2.00000000e+00]])

# %%
y_test
# Out:
# array([ 901000.48823382,  494537.5115455 ,  949404.20066573,
#        1040389.04813578,  794010.01673364,  724033.56045713,
#         998439.23711398,  909713.4350007 ,  792681.51842008,
#         947490.77747782,  774150.04681239,  654466.94540868,
#         217462.44505709, 1034380.20416167,  530476.12327498,
#         194353.73613998,  441315.08847494,  354744.63059531,
#         755402.37269125,  348893.55395287,  763645.6101594 ,
#         475767.3504504 ,  676108.85120969,  887527.90717999,
#         438250.17615462,  402213.42189319,  472657.61431723,
#         453579.10553422,  191907.65250489,  489595.41246134,
#         270230.63769828,  893926.62947207,  771922.84982131,
#         338350.59543444,  457643.09804238,  775773.2237663 ,
#         474659.86005528,  570399.74276779,  280961.68038979,
#         147601.55157708,  300656.0790682 ,  307101.68583856,
#         486872.05670913,  304653.63604893, 1092026.89678641,
# ...

# %% [markdown]
# # Model Regresi

# %%
from sklearn.linear_model import LinearRegression
regresi =LinearRegression()

# %%
regresi.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Visualisasi Data dan Garis Regresi

# %%
independent_column = dshouse.columns[dshouse.columns != 'House_Price']
for column in independent_column :
    plt.figure(figsize=(6, 4))
    sns.regplot(x=dshouse[column],y=dshouse['House_Price'],scatter_kws={'alpha': 0.5},line_kws={"color": "red"})
    plt.xlabel(column)
    plt.ylabel('House_Price')
    plt.title(f'garis regresi {column} vs House Price')
    plt.show()

# %% [markdown]
# # Testing Model

# %%
y_prediksi = regresi.predict(x_test)
print(y_prediksi)
# Out:
# [ 868714.80177459  490366.07916607  945176.67635361 1032563.13528874
#   776233.80697146  731772.93352122  995173.15246634  885136.69959266
#   796197.49225972  931188.10178834  759146.40127321  645052.25694643
#   218300.96793929 1046435.37118452  537310.87439779  187777.62211307
#   456859.29790882  357673.45890825  742584.51666574  362409.07012776
#   774845.0271195   477971.65569105  680832.18458484  889140.20714907
#   447533.78610352  397244.82302043  453581.78345651  442234.00073335
#   187383.44367588  491340.21749191  279945.94941402  895192.00108951
#   783527.84341155  351872.83205275  478427.56836916  765911.48386555
#   474549.1886118   572483.55886348  303609.63935498  154452.40956481
#   304198.65835588  299873.55114402  507846.9811176   309627.95967072
#  1082015.40800963 1011117.46745844  759610.39517033  807615.57050303
#  1025677.13855413  692420.08206648  282071.57166183  753369.35143812
#   812889.46457263  716571.46069528  542520.84653835  801922.57076514
# ...

# %% [markdown]
# # Test Data Baru

# %%
data_baru = pd.DataFrame({
    'Square_Footage': (80, 120, 20, 27, 67, 34, 26, 30, 22, 10),  
    'Num_Bedrooms': (1, 90, 10, 22, 45, 76, 45, 13, 22, 20),  
    'Num_Bathrooms': (0, 60, 10, 15, 65, 23, 49, 50, 22, 11),  
    'Year_Built': (0, 60, 10, 90, 46, 78, 66, 89, 11, 56),  
    'Lot_Size': (60, 50, 10, 48, 22, 30, 57, 25, 68, 70),  
    'Garage_Size': (60, 150, 10, 13, 44, 60, 90, 22, 80, 77),  
    'Neighborhood_Quality': (100, 500, 10, 66, 45, 23, 14, 55, 79, 90),  
})
predictions_data_baru = regresi.predict(data_baru)
data_baru['Predicted House Price'] = predictions_data_baru
print(data_baru)
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              80             1              0           0        60
# 1             120            90             60          60        50
# 2              20            10             10          10        10
# 3              27            22             15          90        48
# 4              67            45             65          46        22
# 5              34            76             23          78        30
# 6              26            45             49          66        57
# 7              30            13             50          89        25
# 8              22            22             22          11        68
# 9              10            20             11          56        70
#
#    Garage_Size  Neighborhood_Quality  Predicted House Price
# 0           60                   100          -8.128418e+05
# 1          150                   500           1.002350e+06
# ...

# %% [markdown]
# # Analisis Korelasi

# %%
dshouse.corr(method='pearson')
# Out:
#                       Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  \
# Square_Footage              1.000000     -0.043564      -0.031584   -0.022392
# Num_Bedrooms               -0.043564      1.000000       0.022848   -0.015820
# Num_Bathrooms              -0.031584      0.022848       1.000000   -0.021063
# Year_Built                 -0.022392     -0.015820      -0.021063    1.000000
# Lot_Size                    0.089479     -0.009355       0.034923   -0.061050
# Garage_Size                 0.030593      0.113761       0.024846   -0.025485
# Neighborhood_Quality       -0.008357     -0.049024       0.017585   -0.009549
# House_Price                 0.991261      0.014633      -0.001862    0.051967
#
#                       Lot_Size  Garage_Size  Neighborhood_Quality  House_Price
# Square_Footage        0.089479     0.030593             -0.008357     0.991261
# Num_Bedrooms         -0.009355     0.113761             -0.049024     0.014633
# ...

# %% [markdown]
# # Save Model

# %%
import pickle
filname = 'house.sav'
pickle.dump(regresi, open(filname,'wb'))
